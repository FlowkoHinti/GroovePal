# %%
from pathlib import Path

import symusic

# %%
# Paths
BASE_PATH = Path.cwd().parent
DATA_PATH = BASE_PATH / 'Data'

# %%
path = DATA_PATH / 'pre_training' / 'test' / 'giga_1036.mid'

with open(path, 'rb') as file:
    score = symusic.Score.from_midi(file.read())
score
# Out:
# Score(ttype=Tick, tpq=240, begin=0, end=5760, tracks=6, notes=66, time_sig=1, key_sig=0, markers=0)

# %%
score.tracks
# Out:
# symusic.core.TrackTickList([Track(ttype=Tick, program=0, is_drum=false, name=Bass Drum 1, notes=10, lyrics=0), Track(ttype=Tick, program=0, is_drum=false, name=Acoustic Snare, notes=11, lyrics=0), Track(ttype=Tick, program=0, is_drum=false, name=Closed High-Hat, notes=42, lyrics=0), Track(ttype=Tick, program=0, is_drum=false, name=Pedal High Hat, notes=1, lyrics=0), Track(ttype=Tick, program=0, is_drum=false, name=Open High Hat, notes=1, lyrics=0), Track(ttype=Tick, program=0, is_drum=false, name=Crash Cymbal 2, notes=1, lyrics=0)])

# %%
score.tracks[0]
# Out:
# Track(ttype=Tick, program=0, is_drum=false, name=Bass Drum 1, notes=10, lyrics=0)
