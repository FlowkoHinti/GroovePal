# %%
import json
import os
from typing import  Union
from pathlib import Path

import pandas as pd

# %%
def load_dna_json(dna_path: str):
    """Load DNA data from .json (list) or .jsonl (one JSON object per line)."""
    if dna_path.endswith(".jsonl"):
        records = []
        with open(dna_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if line:
                    records.append(json.loads(line))
        return records
    else:
        # .json
        with open(dna_path, "rb") as f:
            return json.load(f)  # expected to be a list


def get_all_dna_json_paths(dna_path: Union[str, os.PathLike]):
    """Return all DNA JSON/JSONL file paths in the directory."""
    all_files = [f for f in os.listdir(dna_path) if f.endswith(".json") or f.endswith(".jsonl")]
    if not all_files:
        raise FileNotFoundError(f'No DNA JSON/JSONL files found in {dna_path}')
    # Prefer .jsonl order first (optional), then .json
    all_files.sort(key=lambda x: (not x.endswith(".jsonl"), x))
    return [os.path.join(dna_path, f) for f in all_files]

# %%
path = (Path(os.getcwd())).parent / 'Data' / 'intermediate'
path
# Out:
# WindowsPath('C:/Users/minem/PycharmProjects/ITS-M/Master/GroovePal/Data/intermediate')

# %%
train_paths = get_all_dna_json_paths(path / 'train')
test_paths = get_all_dna_json_paths(path / 'test')
valid_paths = get_all_dna_json_paths(path / 'validation')

paths = train_paths + test_paths + valid_paths
paths
# Out:
# ['C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_1.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_10.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_11.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_12.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_13.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_14.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_15.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_16.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_17.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_18.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_19.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_2.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_3.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_4.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_5.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_6.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_7.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_8.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\train\\train_chunk_9.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\test\\test_chunk_1.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\test\\test_chunk_2.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\test\\test_chunk_3.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\validation\\validation_chunk_1.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\validation\\validation_chunk_2.jsonl',
#  'C:\\Users\\minem\\PycharmProjects\\ITS-M\\Master\\GroovePal\\Data\\intermediate\\validation\\validation_chunk_3.jsonl']

# %%
dnas = []
for json_path in paths:
    dna = load_dna_json(json_path)
    dnas.extend(dna)

# %%
len(dnas)
# Out:
# 49210

# %%
df = pd.DataFrame(dnas)
df
# Out:
#             DNA_ID StyleTags  \
# 0         groove_0        []
# 1         groove_1        []
# 2        groove_10        []
# 3       groove_100        []
# 4      groove_1000        []
# ...            ...       ...
# 49205  groove_5026        []
# 49206  groove_5027        []
# 49207  groove_5028        []
# 49208  groove_5029        []
# 49209  groove_5030        []
#
#                                                 DNAUnits  Bpm  GridFactor  \
# 0      [{'Value': 0, 'ExcludeValue': None, 'Wildcard'...   80           4
# 1      [{'Value': 0, 'ExcludeValue': None, 'Wildcard'...   80           4
# 2      [{'Value': 0, 'ExcludeValue': None, 'Wildcard'...   80           4
# 3      [{'Value': 7, 'ExcludeValue': None, 'Wildcard'...  120           4
# 4      [{'Value': 2, 'ExcludeValue': None, 'Wildcard'...   95           4
# ...                                                  ...  ...         ...
# 49205  [{'Value': 5, 'ExcludeValue': None, 'Wildcard'...  100           4
# 49206  [{'Value': 5, 'ExcludeValue': None, 'Wildcard'...  100           4
# 49207  [{'Value': 5, 'ExcludeValue': None, 'Wildcard'...  100           4
# 49208  [{'Value': 5, 'ExcludeValue': None, 'Wildcard'...  100           4
# 49209  [{'Value': 5, 'ExcludeValue': None, 'Wildcard'...  100           4
#
#        Numerator  Denominator  TicksPerQuarterNote  NumberOfBars  \
# 0              4            4                  480            28
# 1              4            4                  480            28
# 2              4            4                  480            28
# 3              4            4                  480           103
# 4              4            4                  480             0
# ...          ...          ...                  ...           ...
# 49205          4            4                  480             4
# 49206          4            4                  480             4
# 49207          4            4                  480             4
# 49208          4            4                  480             4
# 49209          4            4                  480             4
#
#        TicksPerGridUnit  FillStartTicks
# 0                   120               0
# 1                   120               0
# 2                   120               0
# 3                   120               0
# 4                   120               0
# ...                 ...             ...
# 49205               120               0
# 49206               120               0
# 49207               120               0
# 49208               120               0
# 49209               120               0
#
# [49210 rows x 11 columns]

# %%
df['Unit_lengths'] = df['DNAUnits'].apply(len)
df['Unit_lengths']
# Out:
# 0         463
# 1         463
# 2         463
# 3        1661
# 4          13
#          ...
# 49205      65
# 49206      65
# 49207      65
# 49208      65
# 49209      65
# Name: Unit_lengths, Length: 49210, dtype: int64

# %%
less_than_1024 = df['Unit_lengths'] < 1024
less_than_1024
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 49205     True
# 49206     True
# 49207     True
# 49208     True
# 49209     True
# Name: Unit_lengths, Length: 49210, dtype: bool

# %%
units = [unit for lst_units in df["DNAUnits"] for unit in lst_units]
units = pd.DataFrame(units)

# %%
units
# Out:
#           Value ExcludeValue  Wildcard  AvgOffsetTicks  AvgVelocity  \
# 0             0         None     False               0     0.000000
# 1             0         None     False               0     0.000000
# 2             0         None     False               0     0.000000
# 3             0         None     False               0     0.000000
# 4             0         None     False               0     0.000000
# ...         ...          ...       ...             ...          ...
# 13779824      5         None     False             -36     0.484252
# 13779825      0         None     False               0     0.000000
# 13779826      5         None     False             -41     0.460630
# 13779827      0         None     False               0     0.000000
# 13779828      5         None     False             -40     0.480315
#
#          OffsetTicksPerValuePart  \
# 0                             {}
# 1                             {}
# 2                             {}
# 3                             {}
# 4                             {}
# ...                          ...
# 13779824    {'4': -32, '1': -40}
# 13779825                      {}
# 13779826    {'4': -32, '1': -50}
# 13779827                      {}
# 13779828    {'1': -40, '4': -41}
#
#                                        VelocityPerValuePart  IsEmpty
# 0                                                        {}     True
# 1                                                        {}     True
# 2                                                        {}     True
# 3                                                        {}     True
# 4                                                        {}     True
# ...                                                     ...      ...
# 13779824  {'4': 0.44881889763779526, '1': 0.519685039370...    False
# 13779825                                                 {}     True
# 13779826  {'4': 0.4409448818897638, '1': 0.4803149606299...    False
# 13779827                                                 {}     True
# 13779828  {'1': 0.6062992125984252, '4': 0.3543307086614...    False
#
# [13779829 rows x 8 columns]
